# %% [markdown]
# # 첫번째 코랩 파일 생성하기

# %% [markdown]
# ## 1. Hello World! 출력하기

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## 2. Tensorflow 모듈 Import 하기

# %%
import tensorflow as tf

# %% [markdown]
# ## 3. 모듈 버전 확인하기

# %%
tf.__version__
# Out:
# '2.21.0'

# %% [markdown]
# ### 참고 : Python class

# %%
class Dog :

  def __init__(self, name, color, size) :
    self.name = name
    self.color = color
    self.size = size

  def bark(self) :
    print("멍멍")

pet = Dog("멍멍이", "검정색", "중형")
print(pet.name, pet.color, pet.size)
pet.bark()
# Out:
# 멍멍이 검정색 중형
# 멍멍

# %% [markdown]
# ### 참고 : Python Import 문법

# %%
#import module_name  # 모듈 전체 가져오기
#import module_name as alias  # 모듈을 별칭(alias)으로 가져오기
#from module_name import specific_function  # 특정 함수만 가져오기
#from module_name import *  # 모듈의 모든 기능 가져오기 (권장 X)

# %% [markdown]
# ## 깃허브 연동하기

# %%
# !cd ml
# Out:
# zsh:cd:1: no such file or directory: ml

# %%
# !git clone https://hsmu-jeongeun:{xxx}@github.com/hsmu-jeongeun/machine-learning-practice.git
# Out:
# Cloning into 'machine-learning-practice'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 83 (delta 31), reused 23 (delta 23), pack-reused 40 (from 1)
# Receiving objects: 100% (83/83), 11.82 MiB | 4.23 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# !git config --global user.email 'hsmu.jekim@gmail.com'
# !git config --global user.name 'hsmu-jeongeun'
# !git config --list
# Out:
# credential.helper=osxkeychain
# init.defaultbranch=main
# user.name=hsmu-jeongeun
# user.email=hsmu.jekim@gmail.com
