# %% [markdown]
# # 나의 첫 번째 코랩
#
# ## 실습 내용
#
# - 실습1: Google의 Folab으로 첫 번째 파일 생성
# - 실습2: Git 레포지토리 생성
# - 실습3: Colab 제공 기능으로 Github에 업로드하기

# %% [markdown]
# ## Hello World 출력하기
#
# - print 함수 사용

# %%
print()  # 프린트하는 함수

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # 2. Tensorflow 모듈 불러오기

# %%
import tensorflow as tf
